# %%
customer_name = input("Enter customer name: ")

items = []
grand_total = 0

while True:
    item = input("Enter item name: ")
    price = int(input("Enter price: "))
    qty = int(input("Enter quantity: "))
    
    total = price * qty
    grand_total += total
    
    items.append({"name": item, "price": price, "qty": qty, "total": total})
    
    another = input("Do you want to buy another item? (yes/no): ")
    if another != "yes":
        break

print("\n===== BILL =====")
print(f"Customer: {customer_name}")
print("- " * 20)

for i, item in enumerate(items, 1):
    print(f"{i}. {item['name']}  Price: {item['price']}  Qty: {item['qty']}  Total: {item['total']}")
    print("- " * 20)

print(f"Grand Total: {grand_total}")
# Out:
# ===== BILL =====
# Customer: nitya
# - - - - - - - - - - - - - - - - - - - -
# 1. mobile cover  Price: 600000  Qty: 1  Total: 600000
# - - - - - - - - - - - - - - - - - - - -
# Grand Total: 600000

# %%
#create a set with five unique numbers and print it.
a={1,2,3,4}
b={2,3,4,5}

print(a|b)
print(a&b)
print(a-b)
print(a^b)
# Out:
# {1, 2, 3, 4, 5}
# {2, 3, 4}
# {1}
# {1, 5}

# %%
n={1,2,3,4}
print(type(n))
# Out:
# <class 'set'>

# %%
#Convert a list into a set to remove duplicates.
num=[1,2,3,4,5]
unique_num=set(num)
print(unique_num)
# Out:
# {1, 2, 3, 4, 5}

# %%
#add a element to an existing set.
fruits={"apple","banana"}
fruits.add("orange")
print(fruits)
# Out:
# {'banana', 'apple', 'orange'}

# %%
num={1,2,3}
num.add(4)
print(num)
# Out:
# {1, 2, 3, 4}

# %%
#update number in a set
numbers={1,2,3}
numbers.update([4,5,6])
print(numbers)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
nums=[1,2,2,3,4,5,6]
unique_nums=set(nums)
print(unique_nums)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
a={1,2,3}
b={3,4,5}
print(a.union(b))
print(a.intersection(b))
print(a.difference(b))
print(a.symmetric_difference(b))
# Out:
# {1, 2, 3, 4, 5}
# {3}
# {1, 2}
# {1, 2, 4, 5}

# %%
# Students enrolled in two course. Find students enrolled in both.
# Solution:
python_students={"Ram","Shyam","Sandesh"}
django_students={"Sandesh","Raju","nityalal"}
print(python_students.intersection(django_students))
print(len(python_students)+len(django_students))
print(python_students | django_students)
# Out:
# {'Sandesh'}
# 6
# {'Shyam', 'Ram', 'Sandesh', 'Raju', 'nityalal'}

# %%
#Exerecise 1: store data in a list.
#Question: Create a list of 5 students names and display them one by one.
students=["raju","sandesh","nitesh","indu","saurav"]

for students in students:
    print(students)
# Out:
# raju
# sandesh
# nitesh
# indu
# saurav

# %%
#Exercise 2: Add students dynamically.
#Questionn: Take 3 student names from user input and store them in a list.
students=[]
for i in range(3):
    name=input("Enter student name:")
    students.append(name)
    print("Student list:", students)
# Out:
# Student list: ['sandesh']
# Student list: ['sandesh', 'nitesh']
# Student list: ['sandesh', 'nitesh', 'indu']

# %%
#Exercise 3: Tuples for immutable data.
#Question : Store Students grades using tuples.
grades=("A","B","A+","C","B+")
print(grades)
# Out:
# ('A', 'B', 'A+', 'C', 'B+')

# %%
#Exercise 4: Access Tuples Elements.
#Question: Print first and last grade.

grades=("A","B","A+","C","B+")
print(grades)
print(grades[0])
print(grades[-1])
# Out:
# ('A', 'B', 'A+', 'C', 'B+')
# A
# B+

# %%
#Exercise 5: Student Dictionary.
#Question: Store students name and marks using dictionary.

students={
    "name":"Ram",
    "marks":"85"

}
print(students)
print(students["name"])
# Out:
# {'name': 'Ram', 'marks': '85'}
# Ram

# %%
#Exercise 6: Multiply students dictionary.
#Question:Store and print 2 students with marks.

students={
    "Ram":85,
    "Sita":90
}
print(students)
# Out:
# {'Ram': 85, 'Sita': 90}

# %%
#Exercise 7: Add students data dynamically.
#Question: Add students  name and marks using input and print.

students={}
for i in range(3):
    name=input("Enter the name:")
    marks=int(input("Enter marks"))
    students[name]=marks
print(students)
# Out:
# {'sandesh': 99, 'nitesh': 0, 'indu': 0}

# %%
#Exercise 8: set for unique values.
#Question: Store and print students hobbies ensuring no duplicates.

hobbies ={"Reading","Football","Music","Writing"}
print(hobbies)
# Out:
# {'Reading', 'Music', 'Football', 'Writing'}

# %%
#Exercise 9: Remove duplicate name using set.
#Question: Remove duplicate student names.

names=["Ram","Shyam","Gita","Gita"]
hi = set(names)
print(hi)
# Out:
# {'Gita', 'Shyam', 'Ram'}

# %%
"""
Project: Staff management system(core version)

Goal:
Use list +dictionary + loop to manage staff records in a simple system

Features of the system

Add staff details
Store multiple staff members
View all staff records  
Structured data using dictionary inside a main dictionary 



"""

# %%
def grades(score):
    if score>=80: return "A"
    elif score>=60: return "B"
    elif score>=40: return "C"
    else: return "F"
print(grades(75))
# Out:
# B
