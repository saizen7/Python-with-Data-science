# %%
print("Hello")
# Out:
# Hello

# %%
import pandas as pd 
a=[1,7,2]
print(a)
myvar=pd.Series(a)
print("This coloumn, which is converted by series",myvar)
# Out:
# [1, 7, 2]
# This coloumn, which is converted by series 0    1
# 1    7
# 2    2
# dtype: int64

# %%
import pandas as pd

calories = {
    "Day1": 20,
    "Day2": 40,
    "Day3": 50
}

print(calories)
# Out:
# {'Day1': 20, 'Day2': 40, 'Day3': 50}

# %%
import pandas as pd

data = {
    "calories": [420,380,390],
    "duration": [50,40,45]
}

df = pd.DataFrame(data)
print(df)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
#make a data frame into dictionary in pandas

import pandas as pd

data = {
    "Employee_Name": ["Navu", "Indu", "Sandu", "Raju", "Sacchuu","Nitesh","Balen"],
    "Designation": ["Manager", "Developer", "Accountant", "Designer", "HR","Marketing head","Receptionist"],
    "Salary": [50000, 45000, 40000, 42000, 38000,100000,40000]
}


df = pd.DataFrame(data)

print(df)
df.head(7)
# Out:
#   Employee_Name     Designation  Salary
# 0          Navu         Manager   50000
# 1          Indu       Developer   45000
# 2         Sandu      Accountant   40000
# 3          Raju        Designer   42000
# 4       Sacchuu              HR   38000
# 5        Nitesh  Marketing head  100000
# 6         Balen    Receptionist   40000
#   Employee_Name     Designation  Salary
# 0          Navu         Manager   50000
# 1          Indu       Developer   45000
# 2         Sandu      Accountant   40000
# 3          Raju        Designer   42000
# 4       Sacchuu              HR   38000
# 5        Nitesh  Marketing head  100000
# 6         Balen    Receptionist   40000

# %%
df=pd.read_csv("customers-100.csv")
# df=read.excel(file_name.xls)
print(df)
df.head()
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Index              100 non-null    int64
#  1   Customer Id        100 non-null    str
#  2   First Name         100 non-null    str
#  3   Last Name          100 non-null    str
#  4   Company            100 non-null    str
#  5   City               100 non-null    str
#  6   Country            100 non-null    str
#  7   Phone 1            100 non-null    str
#  8   Phone 2            100 non-null    str
#  9   Email              100 non-null    str
#  10  Subscription Date  100 non-null    str
#  11  Website            100 non-null    str
# dtypes: int64(1), str(11)
# memory usage: 9.5 KB

# %%
df.describe()
# Out:
#             Index
# count  100.000000
# mean    50.500000
# std     29.011492
# min      1.000000
# 25%     25.750000
# 50%     50.500000
# 75%     75.250000
# max    100.000000

# %%
df = pd.read_csv("Mobile_data.csv")
df.head(15)
# Out:
#     Unnamed: 0 brand_name                                    model_name  \
# 0            0    ALCATEL          1 1/8GB Bluish Black (5033D-2JALUAA)
# 1            1    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 2            2    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 3            3    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 4            4      Nokia                           1.3 1/16GB Charcoal
# 5            5      Honor                               10 6/64GB Black
# 6            6      Honor                           10 Lite 3/32GB Blue
# 7            7      Honor                          10 Lite 4/64GB Black
# 8            8      Honor                          10 lite 3/128GB Blue
# 9            9      Honor                          10 lite 3/64GB Black
# 10          10      Honor                          10 lite 3/64GB Black
# 11          11      Honor                           10 lite 3/64GB Blue
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1224 entries, 0 to 1223
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      1224 non-null   int64
#  1   brand_name      1224 non-null   str
#  2   model_name      1224 non-null   str
#  3   os              1027 non-null   str
#  4   popularity      1224 non-null   int64
#  5   best_price      1224 non-null   int64
#  6   lowest_price    964 non-null    float64
#  7   highest_price   964 non-null    float64
#  8   sellers_amount  1224 non-null   int64
#  9   screen_size     1222 non-null   float64
#  10  memory_size     1112 non-null   float64
#  11  battery_size    1214 non-null   float64
#  12  release_date    1224 non-null   str
# dtypes: float64(5), int64(4), str(4)
# memory usage: 124.4 KB

# %%
df.describe()
# Out:
#         Unnamed: 0   popularity    best_price  lowest_price  highest_price  \
# count  1224.000000  1224.000000   1224.000000    964.000000     964.000000
# mean    611.500000   612.500000   7941.206699   7716.018672    9883.410788
# std     353.482673   353.482673   8891.836260   8560.959059   11514.936818
# min       0.000000     1.000000    214.000000    198.000000     229.000000
# 25%     305.750000   306.750000   2599.750000   2399.000000    2887.000000
# 50%     611.500000   612.500000   4728.000000   4574.000000    5325.500000
# 75%     917.250000   918.250000   9323.000000   9262.250000   12673.750000
# max    1223.000000  1224.000000  56082.000000  49999.000000   69999.000000
#
#        sellers_amount  screen_size  memory_size  battery_size
# count     1224.000000  1222.000000  1112.000000   1214.000000
# mean        16.743464     5.394378    95.700059   3608.201812
# std         20.597006     1.476991   111.922576   1668.268774
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'brand_name', 'model_name', 'os', 'popularity',
#        'best_price', 'lowest_price', 'highest_price', 'sellers_amount',
#        'screen_size', 'memory_size', 'battery_size', 'release_date'],
#       dtype='str')

# %%
df = df.drop('Unnamed: 0', axis=1)

# %%
df.columns
# Out:
# Index(['brand_name', 'model_name', 'os', 'popularity', 'best_price',
#        'lowest_price', 'highest_price', 'sellers_amount', 'screen_size',
#        'memory_size', 'battery_size', 'release_date'],
#       dtype='str')

# %%
df.head()
# Out:
#   brand_name                                    model_name       os  \
# 0    ALCATEL          1 1/8GB Bluish Black (5033D-2JALUAA)  Android
# 1    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)  Android
# 2    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)  Android
# 3    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)  Android
# 4      Nokia                           1.3 1/16GB Charcoal  Android
#
#    popularity  best_price  lowest_price  highest_price  sellers_amount  \
# 0         422        1690        1529.0         1819.0              36
# 1         323        1803        1659.0         2489.0              36
# 2         299        1803        1659.0         2489.0              36
# 3         287        1803        1659.0         2489.0              36
# 4        1047        1999           NaN            NaN              10
#
#    screen_size  memory_size  battery_size release_date
# 0         5.00          8.0        2000.0       20-Oct
# ...

# %%
df["brand_name"].unique()
# Out:
# <StringArray>
# [     'ALCATEL',        'Nokia',        'Honor',        'Meizu',
#        'realme',      'OnePlus',       'Archos',      'Ulefone',
#           'AGM',         'OPPO',        'Astro',       'Rezone',
#     'Blackview',       'Bravis',          'NUU',       'Lenovo',
#       'UMIDIGI',    'Assistant',    'Crosscall',        'Sharp',
#          'ERGO',        'Tecno',          'CAT',       'DOOGEE',
#        'Xiaomi',          'ZTE',      'Oukitel',        'Cubot',
#        'S-TELL', 'Sigma mobile',      'Coolpad',       'Bluboo',
#            'LG',     'Motorola',      'Philips',           '2E',
#           'Fly',      'Samsung',    'Prestigio',      'myPhone',
#    'BlackBerry',      'KENEKSI',       'Maxcom',       'HUAWEI',
#        'Vernee',      'General',       'Globex',      'Smartex',
#        'Google',         'ASUS',         'Land',        'MAFAM',
#         'Jinga',     'Vodafone',    'Microsoft',     'iOutdoor',
# ...

# %%
df[df["brand_name"] == "vivo"]
df['brand_name'].value_counts()
# Out:
# brand_name
# Samsung         168
# Xiaomi          111
# Apple           102
# Motorola         62
# Sigma mobile     52
#                ...
# Land              1
# MAFAM             1
# Vodafone          1
# Microsoft         1
# LEAGOO            1
# Name: count, Length: 64, dtype: int64
