# %%
print("Sandesh Adhikari")
# Out:
# Sandesh Adhikari

# %%
num=-1
if(num<0):
    print("negative num")
# Out:
# negative num

# %%
a=2
b=3
c=a+b
print(c)
# Out:
# 5

# %%
print(type(1.1))
# Out:
# <class 'float'>

# %%
num1=int(input("Enter the first number"))
num2=int(input("Enter the second number"))
add=num1+num2
sub=num1-num2
multi=num1*num2
div=num1/num2
print("sum of 2 num is",add)
print("sub of 2 num is",sub)
print("multiplication of 2 num is",multi)
print("division of 2 num is",div)
print(f"difference of  {num1} and {num2} is {sub}")
# Out:
# sum of 2 num is 14
# sub of 2 num is -4
# multiplication of 2 num is 45
# division of 2 num is 0.5555555555555556
# difference of  5 and 9 is -4

# %%
num1=int(input("Enter the first number"))
num2=int(input("Enter the second number"))
if num1>num2:
    print("greatest number=",num1)
else:
    print("greatest number=",num2)
# Out:
# greatest number= 0

# %%
print(max(a,b))
# Out:
# 3

# %%
num=int(input("Enter the number"))
if(num%2==0):
 print("even")
else:
 print("odd")
# Out:
# even

# %%
n=int(input("enter the number to be checked"))
if(n>0):
    print(f"{n} is positve")
elif n<0:
     print(f"{n} is negative")    
else:
     print("It is Zero")
# Out:
# 7 is positve

# %%
num1=int(input("Enter the first number"))
num2=int(input("Enter the second number"))
num3=int(input("Enter the third number"))
num4=int(input("Enter the fourth number"))
print("THe greatest num is",max(num1,num2,num3,num4))
# if num1>num2>num3>num4:
#     print("greatest number=",num1)
# elif num2>num1>num3>num4:
#      print("greatest number=",num2)
# elif num3>num1>num2>num4:
#      print("greatest number=",num3)
# else:
#      print("greatest number=",num4)
# Out:
# greatest number= 8

# %%
marks=float(input("Enter the marks"))
if marks>=80:
    print("Distinction")
elif marks>=70:
     print("First Division")
elif marks>=60:
     print("Second Division")  
elif marks>=50:
     print("Third Division") 
else:
     print("Failed")
# Out:
# Third Division

# %%
num1=int(input("Enter the first number"))
num2=int(input("Enter the second number"))
num3=int(input("Enter the third number"))
print("The smallest num is",min(num1,num2,num3))
# Out:
# The smallest num is 0

# %%
print("hhhhh")
"""
kkjhkhkhkk
kkjhkhkhkk
kkjhkhkhkk
kkjhkhkhkk
kkjhkhkhkk
kkjhkhkhkk
kkjhkhkhkk
kkjhkhkhkk



"""
