# %%
print("Hello Ram, Welcome to System")
print("Hello Sits, Welcome to System")
print("Hello Hari, Welcome to System")
print("Hello Osin, Welcome to System")
# Out:
# Hello Ram, Welcome to System/n
# Hello Sits, Welcome to System
# Hello Hari, Welcome to System
# Hello Osin, Welcome to System

# %%
def greet_user(name):
    return f"Hello, {name} !Welcome to the system."
print(greet_user("Ram"))
# Out:
# 'Hello, Ram !Welcome to the system.'

# %%
def calculate_discount(price, discount_percent):
    if discount_percent < 0 or discount_percent > 100:
        return "Invalid discount percentage"
    
    discount_amount = price * discount_percent / 100
    final_price = price - discount_amount
    
    return f"Original Price: {price}, Discount: {discount_percent}%, Final Price: {final_price}"

result = calculate_discount(100, 10)
print(result)
# Out:
# Original Price: 100, Discount: 10%, Final Price: 90.0

# %%
def convert(c):
    f=(c*1.8)+32
    return f
c=int(input("Enter the Centigrade"))
print(f"Fahrenheiht Temperature= {convert(c)}F")

# %%
def sum (i):
    sum=0
    for s in i:
        sum+= s
    return sum
num=[1,2,3,4,5]
sum(num)
# Out:
# 15

# %%
def do(a,b,c,d):
    sum=a+b+c+d
    return sum
do(1,2,3,4)
# Out:
# 10

# %%
def build_profile(**kwwargs):
    return kwwargs
user=build_profile(name="Rishi",age=25, skills=["Python","Django"])
print(user)
# Out:
# {'name': 'Rishi', 'age': 25, 'skills': ['Python', 'Django']}

# %%
# A funtion to clean
# This function should remove all None values and print the clean data 
def clean(data):
    result=[]
    for item in data:
        if type(item)==int or type(item)==float:
            result.append(item)
    return tuple(result)
data=(10,None,30,"No",40,50)
print(clean(data))
# Out:
# (10, 30, 40, 50)
