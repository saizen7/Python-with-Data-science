# %%
print("sandesh")
# Out:
# Nitesh

# %%
import pandas as pd

# reading file
df = pd.read_csv("Mobile_data.csv")

# dataframe information
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1224 entries, 0 to 1223
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      1224 non-null   int64
#  1   brand_name      1224 non-null   str
#  2   model_name      1224 non-null   str
#  3   os              1027 non-null   str
#  4   popularity      1224 non-null   int64
#  5   best_price      1224 non-null   int64
#  6   lowest_price    964 non-null    float64
#  7   highest_price   964 non-null    float64
#  8   sellers_amount  1224 non-null   int64
#  9   screen_size     1222 non-null   float64
#  10  memory_size     1112 non-null   float64
#  11  battery_size    1214 non-null   float64
#  12  release_date    1224 non-null   str
# dtypes: float64(5), int64(4), str(4)
# memory usage: 124.4 KB

# %%
df.head()
# Out:
#    Unnamed: 0 brand_name                                    model_name  \
# 0           0    ALCATEL          1 1/8GB Bluish Black (5033D-2JALUAA)
# 1           1    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 2           2    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 3           3    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 4           4      Nokia                           1.3 1/16GB Charcoal
#
#         os  popularity  best_price  lowest_price  highest_price  \
# 0  Android         422        1690        1529.0         1819.0
# 1  Android         323        1803        1659.0         2489.0
# 2  Android         299        1803        1659.0         2489.0
# 3  Android         287        1803        1659.0         2489.0
# 4  Android        1047        1999           NaN            NaN
#
#    sellers_amount  screen_size  memory_size  battery_size release_date
# 0              36         5.00          8.0        2000.0       20-Oct
# ...

# %%
df.isnull().sum()
df.duplicated().sum()  #it shows how many dupliates are there 
df.drop_duplicates()  # if there is dupicate it will remove that.
# Out:
#       Unnamed: 0    brand_name                                    model_name  \
# 0              0       ALCATEL          1 1/8GB Bluish Black (5033D-2JALUAA)
# 1              1       ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 2              2       ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 3              3       ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 4              4         Nokia                           1.3 1/16GB Charcoal
# ...          ...           ...                                           ...
# 1219        1219         Apple               iPhone XS Max 64GB Gold (MT522)
# 1220        1220         Apple      iPhone XS Max Dual Sim 64GB Gold (MT732)
# 1221        1221        HUAWEI              nova 5T 6/128GB Black (51094MEU)
# 1222        1222           ZTE              nubia Red Magic 5G 8/128GB Black
# 1223        1223  Sigma mobile                             x-style 35 Screen
#
# ...

# %%
# print( "the total  brands are :", df["brand_name"].nunique())
# df["brand_name"].unique()
# df["os"].values_counts()

print("The total brands are :", df["brand_name"].nunique())

print(df["brand_name"].unique())

print(df["os"].value_counts())
# Out:
# The total brands are : 64
# <StringArray>
# [     'ALCATEL',        'Nokia',        'Honor',        'Meizu',
#        'realme',      'OnePlus',       'Archos',      'Ulefone',
#           'AGM',         'OPPO',        'Astro',       'Rezone',
#     'Blackview',       'Bravis',          'NUU',       'Lenovo',
#       'UMIDIGI',    'Assistant',    'Crosscall',        'Sharp',
#          'ERGO',        'Tecno',          'CAT',       'DOOGEE',
#        'Xiaomi',          'ZTE',      'Oukitel',        'Cubot',
#        'S-TELL', 'Sigma mobile',      'Coolpad',       'Bluboo',
#            'LG',     'Motorola',      'Philips',           '2E',
#           'Fly',      'Samsung',    'Prestigio',      'myPhone',
#    'BlackBerry',      'KENEKSI',       'Maxcom',       'HUAWEI',
#        'Vernee',      'General',       'Globex',      'Smartex',
#        'Google',         'ASUS',         'Land',        'MAFAM',
#         'Jinga',     'Vodafone',    'Microsoft',     'iOutdoor',
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0   popularity    best_price  lowest_price  highest_price  \
# count  1224.000000  1224.000000   1224.000000    964.000000     964.000000
# mean    611.500000   612.500000   7941.206699   7716.018672    9883.410788
# std     353.482673   353.482673   8891.836260   8560.959059   11514.936818
# min       0.000000     1.000000    214.000000    198.000000     229.000000
# 25%     305.750000   306.750000   2599.750000   2399.000000    2887.000000
# 50%     611.500000   612.500000   4728.000000   4574.000000    5325.500000
# 75%     917.250000   918.250000   9323.000000   9262.250000   12673.750000
# max    1223.000000  1224.000000  56082.000000  49999.000000   69999.000000
#
#        sellers_amount  screen_size  memory_size  battery_size
# count     1224.000000  1222.000000  1112.000000   1214.000000
# mean        16.743464     5.394378    95.700059   3608.201812
# std         20.597006     1.476991   111.922576   1668.268774
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1224 entries, 0 to 1223
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      1224 non-null   int64
#  1   brand_name      1224 non-null   str
#  2   model_name      1224 non-null   str
#  3   os              1027 non-null   str
#  4   popularity      1224 non-null   int64
#  5   best_price      1224 non-null   int64
#  6   lowest_price    964 non-null    float64
#  7   highest_price   964 non-null    float64
#  8   sellers_amount  1224 non-null   int64
#  9   screen_size     1222 non-null   float64
#  10  memory_size     1112 non-null   float64
#  11  battery_size    1214 non-null   float64
#  12  release_date    1224 non-null   str
# dtypes: float64(5), int64(4), str(4)
# memory usage: 124.4 KB

# %%
df['highest_price'].fillna(299, inplace=True)
df['highest_price'].notnull().sum()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10304\977839184.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['highest_price'].fillna(299, inplace=True)
# np.int64(964)

# %%
newdf=df.fillna(30)
newdf.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1224 entries, 0 to 1223
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      1224 non-null   int64
#  1   brand_name      1224 non-null   str
#  2   model_name      1224 non-null   str
#  3   os              1224 non-null   object
#  4   popularity      1224 non-null   int64
#  5   best_price      1224 non-null   int64
#  6   lowest_price    1224 non-null   float64
#  7   highest_price   1224 non-null   float64
#  8   sellers_amount  1224 non-null   int64
#  9   screen_size     1224 non-null   float64
#  10  memory_size     1224 non-null   float64
#  11  battery_size    1224 non-null   float64
#  12  release_date    1224 non-null   str
# dtypes: float64(5), int64(4), object(1), str(3)
# memory usage: 124.4+ KB

# %%
newdf = df.fillna(30)
newdf.info()
x = df['highest_price'].mean()
newdf=df.fillna(x)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1224 entries, 0 to 1223
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      1224 non-null   int64
#  1   brand_name      1224 non-null   str
#  2   model_name      1224 non-null   str
#  3   os              1224 non-null   object
#  4   popularity      1224 non-null   int64
#  5   best_price      1224 non-null   int64
#  6   lowest_price    1224 non-null   float64
#  7   highest_price   1224 non-null   float64
#  8   sellers_amount  1224 non-null   int64
#  9   screen_size     1224 non-null   float64
#  10  memory_size     1224 non-null   float64
#  11  battery_size    1224 non-null   float64
#  12  release_date    1224 non-null   str
# dtypes: float64(5), int64(4), object(1), str(3)
# memory usage: 124.4+ KB

# %%
df['highest_price'] = df['highest_price'].fillna(
    df.groupby('brand_name')['highest_price'].transform('mean'))
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1224 entries, 0 to 1223
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      1224 non-null   int64
#  1   brand_name      1224 non-null   str
#  2   model_name      1224 non-null   str
#  3   os              1027 non-null   str
#  4   popularity      1224 non-null   int64
#  5   best_price      1224 non-null   int64
#  6   lowest_price    964 non-null    float64
#  7   highest_price   1206 non-null   float64
#  8   sellers_amount  1224 non-null   int64
#  9   screen_size     1222 non-null   float64
#  10  memory_size     1112 non-null   float64
#  11  battery_size    1214 non-null   float64
#  12  release_date    1224 non-null   str
# dtypes: float64(5), int64(4), str(4)
# memory usage: 124.4 KB

# %%
df["highes_price"] = df['highest_price'].fillna(df['highest_price'].mean())
df.info()
df.head
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1224 entries, 0 to 1223
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      1224 non-null   int64
#  1   brand_name      1224 non-null   str
#  2   model_name      1224 non-null   str
#  3   os              1027 non-null   str
#  4   popularity      1224 non-null   int64
#  5   best_price      1224 non-null   int64
#  6   lowest_price    964 non-null    float64
#  7   highest_price   1206 non-null   float64
#  8   sellers_amount  1224 non-null   int64
#  9   screen_size     1222 non-null   float64
#  10  memory_size     1112 non-null   float64
#  11  battery_size    1214 non-null   float64
#  12  release_date    1224 non-null   str
#  13  highes_price    1224 non-null   float64
# dtypes: float64(6), int64(4), str(4)
# memory usage: 134.0 KB
# ...

# %%
df["lowest_price"] = df['lowest_price'].fillna(df['lowest_price'].mean())
df.info()
df.head
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1224 entries, 0 to 1223
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      1224 non-null   int64
#  1   brand_name      1224 non-null   str
#  2   model_name      1224 non-null   str
#  3   os              1027 non-null   str
#  4   popularity      1224 non-null   int64
#  5   best_price      1224 non-null   int64
#  6   lowest_price    1224 non-null   float64
#  7   highest_price   1206 non-null   float64
#  8   sellers_amount  1224 non-null   int64
#  9   screen_size     1222 non-null   float64
#  10  memory_size     1112 non-null   float64
#  11  battery_size    1214 non-null   float64
#  12  release_date    1224 non-null   str
#  13  highes_price    1224 non-null   float64
# dtypes: float64(6), int64(4), str(4)
# memory usage: 134.0 KB
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1224 entries, 0 to 1223
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      1224 non-null   int64
#  1   brand_name      1224 non-null   str
#  2   model_name      1224 non-null   str
#  3   os              1027 non-null   str
#  4   popularity      1224 non-null   int64
#  5   best_price      1224 non-null   int64
#  6   lowest_price    1224 non-null   float64
#  7   highest_price   1206 non-null   float64
#  8   sellers_amount  1224 non-null   int64
#  9   screen_size     1222 non-null   float64
#  10  memory_size     1112 non-null   float64
#  11  battery_size    1214 non-null   float64
#  12  release_date    1224 non-null   str
#  13  highes_price    1224 non-null   float64
# dtypes: float64(6), int64(4), str(4)
# memory usage: 134.0 KB

# %%
df.head(10)
# Out:
#    Unnamed: 0 brand_name                                    model_name  \
# 0           0    ALCATEL          1 1/8GB Bluish Black (5033D-2JALUAA)
# 1           1    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 2           2    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 3           3    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 4           4      Nokia                           1.3 1/16GB Charcoal
# 5           5      Honor                               10 6/64GB Black
# 6           6      Honor                           10 Lite 3/32GB Blue
# 7           7      Honor                          10 Lite 4/64GB Black
# 8           8      Honor                          10 lite 3/128GB Blue
# 9           9      Honor                          10 lite 3/64GB Black
#
#         os  popularity  best_price  lowest_price  highest_price  \
# 0  Android         422        1690   1529.000000    1819.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1224 entries, 0 to 1223
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      1224 non-null   int64
#  1   brand_name      1224 non-null   str
#  2   model_name      1224 non-null   str
#  3   os              1027 non-null   str
#  4   popularity      1224 non-null   int64
#  5   best_price      1224 non-null   int64
#  6   lowest_price    1224 non-null   float64
#  7   highest_price   1206 non-null   float64
#  8   sellers_amount  1224 non-null   int64
#  9   screen_size     1222 non-null   float64
#  10  memory_size     1112 non-null   float64
#  11  battery_size    1214 non-null   float64
#  12  release_date    1224 non-null   str
#  13  highes_price    1224 non-null   float64
# dtypes: float64(6), int64(4), str(4)
# memory usage: 134.0 KB

# %%
df=df.dropna(subset=['os'])
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1027 entries, 0 to 1222
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      1027 non-null   int64
#  1   brand_name      1027 non-null   str
#  2   model_name      1027 non-null   str
#  3   os              1027 non-null   str
#  4   popularity      1027 non-null   int64
#  5   best_price      1027 non-null   int64
#  6   lowest_price    1027 non-null   float64
#  7   highest_price   1015 non-null   float64
#  8   sellers_amount  1027 non-null   int64
#  9   screen_size     1026 non-null   float64
#  10  memory_size     1027 non-null   float64
#  11  battery_size    1017 non-null   float64
#  12  release_date    1027 non-null   str
#  13  highes_price    1027 non-null   float64
# dtypes: float64(6), int64(4), str(4)
# memory usage: 120.4 KB

# %%
df=df.dropna(subset=['screen_size'])
df=df.dropna(subset=['battery_size'])
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1016 entries, 0 to 1222
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      1016 non-null   int64
#  1   brand_name      1016 non-null   str
#  2   model_name      1016 non-null   str
#  3   os              1016 non-null   str
#  4   popularity      1016 non-null   int64
#  5   best_price      1016 non-null   int64
#  6   lowest_price    1016 non-null   float64
#  7   highest_price   1004 non-null   float64
#  8   sellers_amount  1016 non-null   int64
#  9   screen_size     1016 non-null   float64
#  10  memory_size     1016 non-null   float64
#  11  battery_size    1016 non-null   float64
#  12  release_date    1016 non-null   str
#  13  highes_price    1016 non-null   float64
# dtypes: float64(6), int64(4), str(4)
# memory usage: 119.1 KB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0         0
# brand_name         0
# model_name         0
# os                 0
# popularity         0
# best_price         0
# lowest_price       0
# highest_price     12
# sellers_amount     0
# screen_size        0
# memory_size        0
# battery_size       0
# release_date       0
# highes_price       0
# dtype: int64

# %%
df=df.dropna(subset=['highest_price'])
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1004 entries, 0 to 1222
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      1004 non-null   int64
#  1   brand_name      1004 non-null   str
#  2   model_name      1004 non-null   str
#  3   os              1004 non-null   str
#  4   popularity      1004 non-null   int64
#  5   best_price      1004 non-null   int64
#  6   lowest_price    1004 non-null   float64
#  7   highest_price   1004 non-null   float64
#  8   sellers_amount  1004 non-null   int64
#  9   screen_size     1004 non-null   float64
#  10  memory_size     1004 non-null   float64
#  11  battery_size    1004 non-null   float64
#  12  release_date    1004 non-null   str
#  13  highes_price    1004 non-null   float64
# dtypes: float64(6), int64(4), str(4)
# memory usage: 117.7 KB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0        0
# brand_name        0
# model_name        0
# os                0
# popularity        0
# best_price        0
# lowest_price      0
# highest_price     0
# sellers_amount    0
# screen_size       0
# memory_size       0
# battery_size      0
# release_date      0
# highes_price      0
# dtype: int64

# %%
df.describe()
# Out:
#         Unnamed: 0   popularity    best_price  lowest_price  highest_price  \
# count  1004.000000  1004.000000   1004.000000   1004.000000    1004.000000
# mean    618.858566   655.301793   9338.481076   8880.043011   11227.532207
# std     340.946419   355.174036   9006.116317   7650.739651   10818.709026
# min       0.000000     2.000000    840.000000    899.000000     446.583333
# 25%     348.750000   351.750000   3528.500000   3999.000000    4137.750000
# 50%     624.500000   680.500000   5572.000000   7697.509336    6471.812500
# 75%     889.250000   967.250000  12078.250000   8475.500000   15491.733333
# max    1222.000000  1224.000000  55338.000000  45799.000000   64999.000000
#
#        sellers_amount  screen_size  memory_size  battery_size  highes_price
# count     1004.000000  1004.000000  1004.000000   1004.000000   1004.000000
# mean        15.981076     5.999203   104.183267   3993.383466  11227.532207
# ...

# %%
df['lowest_price'] = df['lowest_price'].astype(int)
df['release_date'] = pd.to_datetime(df['release_date'])
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1004 entries, 0 to 1222
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      1004 non-null   int64
#  1   brand_name      1004 non-null   str
#  2   model_name      1004 non-null   str
#  3   os              1004 non-null   str
#  4   popularity      1004 non-null   int64
#  5   best_price      1004 non-null   int64
#  6   lowest_price    1004 non-null   int64
#  7   highest_price   1004 non-null   float64
#  8   sellers_amount  1004 non-null   int64
#  9   screen_size     1004 non-null   float64
#  10  memory_size     1004 non-null   float64
#  11  battery_size    1004 non-null   float64
#  12  release_date    1004 non-null   datetime64[us]
#  13  highes_price    1004 non-null   float64
# dtypes: datetime64[us](1), float64(5), int64(5), str(3)
# memory usage: 117.7 KB
# ...

# %%
df= df.rename(columns={'highest_price': 'Expensive_price'})
df.columns = df.columns.str.replace("_"," ")
# df.info()
df.head()
# Out:
#    Unnamed: 0 brand name                                    model name  \
# 0           0    ALCATEL          1 1/8GB Bluish Black (5033D-2JALUAA)
# 1           1    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 2           2    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 3           3    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
# 4           4      Nokia                           1.3 1/16GB Charcoal
#
#         os  popularity  best price  lowest price  Expensive price  \
# 0  Android         422        1690          1529      1819.000000
# 1  Android         323        1803          1659      2489.000000
# 2  Android         299        1803          1659      2489.000000
# 3  Android         287        1803          1659      2489.000000
# 4  Android        1047        1999          7716      3185.263158
#
#    sellers amount  screen size  memory size  battery size release date  \
# ...

# %%
df.to_csv("Clean_data")
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1004 entries, 0 to 1222
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       1004 non-null   int64
#  1   brand name       1004 non-null   str
#  2   model name       1004 non-null   str
#  3   os               1004 non-null   str
#  4   popularity       1004 non-null   int64
#  5   best price       1004 non-null   int64
#  6   lowest price     1004 non-null   int64
#  7   Expensive price  1004 non-null   float64
#  8   sellers amount   1004 non-null   int64
#  9   screen size      1004 non-null   float64
#  10  memory size      1004 non-null   float64
#  11  battery size     1004 non-null   float64
#  12  release date     1004 non-null   datetime64[us]
#  13  highes price     1004 non-null   float64
# dtypes: datetime64[us](1), float64(5), int64(5), str(3)
# memory usage: 117.7 KB

# %%
import matplotlib.pyplot as plt

# plt.hist(df["brand_name",df['popularity']])
plt.bar(df['os'],df['popularity'])
plt.xticks(rotation = 45)
# Out:
# ([0, 1, 2, 3, 4, 5],
#  [Text(0, 0, 'Android'),
#   Text(1, 0, 'iOS'),
#   Text(2, 0, 'OxygenOS'),
#   Text(3, 0, 'WindowsPhone'),
#   Text(4, 0, 'EMUI'),
#   Text(5, 0, 'KAIOS')])

# %%
df['os'].value_counts().plot(kind="pie")
# Out:
# <Axes: >

# %%
df['os'].value_counts().plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['brand name'].value_counts().plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
plt.plot(df['Expensive price'], df['lowest price'])
plt.xlabel("Expensive price")
plt.ylabel("Lowest price")
plt.show()

# %%
plt.scatter(df['Expensive price'], df['lowest price'])
plt.xlabel("Expensive price")
plt.ylabel("Lowest price")
plt.show()
