# %%
print("Hello")
# Out:
# Hello

# %%
import numpy as np

arr = np.array([1,2,3])
print(arr)
print(type(arr))
# Out:
# [1 2 3]
# <class 'numpy.ndarray'>

# %%
x=np.array(34)
print(x)
# Out:
# 34

# %%
#2D Array
arr =np.array([
    [10,20,30],[40,50,60]
])
print(arr)
# Out:
# [[10 20 30]
#  [40 50 60]]

# %%
arr=np.array([1,2,3,4], ndmin=3)
print(arr)
print('number of dimension',arr.ndim)
# Out:
# [[[1 2 3 4]]]
# number of dimension 3

# %%
arr=np.array=([1,2,3,4,5,6,7])
x=arr[1:6]
print("The value of variable x is",x)

#print(arr[1:5])
#negative slicing----Use the minus operator to refer to a index from the end:
# Out:
# The value of variable x is [2, 3, 4, 5, 6]

# %%
arr = np.array=([1,2,3,4,5,6,7])
print(arr[1:5:2])
# Out:
# [2, 4]

# %%
import numpy as np
a = np.array([1,2,3,4])
b = np.array(["Sandesh","Nitesh","Indresh"])

print(a.dtype)
print(b.dtype)
# Out:
# int64
# <U7

# %%
a=np.array([1,2,3,4],dtype='O')
b=np.array(["Sandesh","Indresh","Nitesh","Saurav"])
print(a.dtype)
#print(b.dtype)
# Out:
# object

# %%
import numpy as np
a = np.array([1,2,3,4], dtype='i2')
b = np.array(["Sandesh","Nitesh","Indresh",2,3])

print(a.dtype)
print(b.dtype)
# Out:
# int16
# <U21

# %%
a=np.array([1,2,3,4],dtype='i')
print(a.dtype)
# Out:
# int32

# %%
a=np.array([True,False],dtype='bool')
print(a.dtype)
# Out:
# bool

# %%
a = np.array([0,1,2], dtype='u8')
print(a.dtype)
# Out:
# uint64

# %%
a=np.array([1,5,2,7],dtype='f')
print(a.dtype)
# Out:
# float32

# %%
a=np.array([1+2j,2+3j],dtype='complex')
print(a.dtype)
# Out:
# complex128

# %%
a = np.array(["2004-01-29"],dtype='M')
print(a.dtype)
# Out:
# datetime64[D]

# %%
a=np.array([1,2,3,4],dtype='O')
print(a.dtype)
# Out:
# object

# %%
a=np.array([1,2,3,4],dtype='timedelta64')
print(a.dtype)
# Out:
# timedelta64

# %%
a=np.array([],dtype='V')
print(a.dtype)
